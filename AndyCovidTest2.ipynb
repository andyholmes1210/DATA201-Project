# %% [markdown]
# ## Updated/tidied code

# %%
library(visdat)
suppressWarnings(library(tidyverse))
library(readxl)

# %%
#reading in covid data
covid_data = read_csv('covid_19_data_portal.csv')
# Out:
# Rows: 125617 Columns: 9
#
# -- Column specification --------------------------------------------------------
# Delimiter: ","
# chr (8): class, category, indicator_name, series_name, sub_series_name, para...
# dbl (1): value
#
#
# i Use `spec()` to retrieve the full column specification for this data.
# i Specify the column types or set `show_col_types = FALSE` to quiet this message.

# %%
#selecting pertinent columns from data set

`%!in%` <- Negate(`%in%`)

monthly_jobseeking_data <- covid_data %>% 
    select(class, category, indicator_name, 
           Region=series_name, Date=parameter, Jobseeker_benefit= value) %>% #renaming selected columns
    filter(class == "Income support", category == 'Benefits', indicator_name == 'Jobseeker support by MSD region', Region %!in% c('Total'))

monthly_jobseeking_data
# Out:
#     class          category indicator_name                  Region
# 1   Income support Benefits Jobseeker support by MSD region Auckland metro
# 2   Income support Benefits Jobseeker support by MSD region Auckland metro
# 3   Income support Benefits Jobseeker support by MSD region Auckland metro
# 4   Income support Benefits Jobseeker support by MSD region Auckland metro
# 5   Income support Benefits Jobseeker support by MSD region Auckland metro
# 6   Income support Benefits Jobseeker support by MSD region Auckland metro
# 7   Income support Benefits Jobseeker support by MSD region Auckland metro
# 8   Income support Benefits Jobseeker support by MSD region Auckland metro
# 9   Income support Benefits Jobseeker support by MSD region Auckland metro
# 10  Income support Benefits Jobseeker support by MSD region Auckland metro
# 11  Income support Benefits Jobseeker support by MSD region Auckland metro
# 12  Income support Benefits Jobseeker support by MSD region Auckland metro
# 13  Income support Benefits Jobseeker support by MSD region Auckland metro
# 14  Income support Benefits Jobseeker support by MSD region Auckland metro
# 15  Income support Benefits Jobseeker support by MSD region Auckland metro
# 16  Income support Benefits Jobseeker support by MSD region Auckland metro
# 17  Income support Benefits Jobseeker support by MSD region Auckland metro
# 18  Income support Benefits Jobseeker support by MSD region Auckland metro
# 19  Income support Benefits Jobseeker support by MSD region Auckland metro
# 20  Income support Benefits Jobseeker support by MSD region Auckland metro
# 21  Income support Benefits Jobseeker support by MSD region Auckland metro
# 22  Income support Benefits Jobseeker support by MSD region Auckland metro
# 23  Income support Benefits Jobseeker support by MSD region Auckland metro
# 24  Income support Benefits Jobseeker support by MSD region Auckland metro
# 25  Income support Benefits Jobseeker support by MSD region Auckland metro
# 26  Income support Benefits Jobseeker support by MSD region Auckland metro
# 27  Income support Benefits Jobseeker support by MSD region Auckland metro
# 28  Income support Benefits Jobseeker support by MSD region Auckland metro
# 29  Income support Benefits Jobseeker support by MSD region Auckland metro
# 30  Income support Benefits Jobseeker support by MSD region Auckland metro
# ... ...            ...      ...                             ...
# 595 Income support Benefits Jobseeker support by MSD region Other region
# 596 Income support Benefits Jobseeker support by MSD region Other region
# 597 Income support Benefits Jobseeker support by MSD region Other region
# 598 Income support Benefits Jobseeker support by MSD region Other region
# 599 Income support Benefits Jobseeker support by MSD region Other region
# 600 Income support Benefits Jobseeker support by MSD region Other region
# 601 Income support Benefits Jobseeker support by MSD region Other region
# 602 Income support Benefits Jobseeker support by MSD region Other region
monthly_jobseeking_data[monthly_jobseeking_data == 'Central'] <- 'MidCentral'
monthly_jobseeking_data[monthly_jobseeking_data == 'Nelson'] <- 'Nelson Marlborough'
monthly_jobseeking_data[monthly_jobseeking_data == 'Wellington'] <- 'Capital & Coast and Hutt Valley'
monthly_jobseeking_data <- monthly_jobseeking_data %>%
    filter(Region != 'Other region') #selecting for all regions that aren't "Other region"

# %%
monthly_jobseeking_data
# Out:
#     class          category indicator_name
# 1   Income support Benefits Jobseeker support by MSD region
# 2   Income support Benefits Jobseeker support by MSD region
# 3   Income support Benefits Jobseeker support by MSD region
# 4   Income support Benefits Jobseeker support by MSD region
# 5   Income support Benefits Jobseeker support by MSD region
# 6   Income support Benefits Jobseeker support by MSD region
# 7   Income support Benefits Jobseeker support by MSD region
# 8   Income support Benefits Jobseeker support by MSD region
# 9   Income support Benefits Jobseeker support by MSD region
# 10  Income support Benefits Jobseeker support by MSD region
# 11  Income support Benefits Jobseeker support by MSD region
# 12  Income support Benefits Jobseeker support by MSD region
# 13  Income support Benefits Jobseeker support by MSD region
# 14  Income support Benefits Jobseeker support by MSD region
# 15  Income support Benefits Jobseeker support by MSD region
# 16  Income support Benefits Jobseeker support by MSD region
# 17  Income support Benefits Jobseeker support by MSD region
# 18  Income support Benefits Jobseeker support by MSD region
# 19  Income support Benefits Jobseeker support by MSD region
# 20  Income support Benefits Jobseeker support by MSD region
# 21  Income support Benefits Jobseeker support by MSD region
# 22  Income support Benefits Jobseeker support by MSD region
# 23  Income support Benefits Jobseeker support by MSD region
# 24  Income support Benefits Jobseeker support by MSD region
# 25  Income support Benefits Jobseeker support by MSD region
# 26  Income support Benefits Jobseeker support by MSD region
# 27  Income support Benefits Jobseeker support by MSD region
# 28  Income support Benefits Jobseeker support by MSD region
# 29  Income support Benefits Jobseeker support by MSD region
# 30  Income support Benefits Jobseeker support by MSD region
# ... ...            ...      ...
# 543 Income support Benefits Jobseeker support by MSD region
# 544 Income support Benefits Jobseeker support by MSD region
# 545 Income support Benefits Jobseeker support by MSD region
# 546 Income support Benefits Jobseeker support by MSD region
# 547 Income support Benefits Jobseeker support by MSD region
# 548 Income support Benefits Jobseeker support by MSD region
# 549 Income support Benefits Jobseeker support by MSD region
# 550 Income support Benefits Jobseeker support by MSD region
# 551 Income support Benefits Jobseeker support by MSD region
# 552 Income support Benefits Jobseeker support by MSD region
# 553 Income support Benefits Jobseeker support by MSD region
# 554 Income support Benefits Jobseeker support by MSD region
# 555 Income support Benefits Jobseeker support by MSD region
# 556 Income support Benefits Jobseeker support by MSD region
# 557 Income support Benefits Jobseeker support by MSD region
# 558 Income support Benefits Jobseeker support by MSD region
# 559 Income support Benefits Jobseeker support by MSD region
# 560 Income support Benefits Jobseeker support by MSD region
# 561 Income support Benefits Jobseeker support by MSD region
# 562 Income support Benefits Jobseeker support by MSD region
# 563 Income support Benefits Jobseeker support by MSD region
# 564 Income support Benefits Jobseeker support by MSD region
# 566 Capital & Coast and Hutt Valley 2021-08-06 14982
# 567 Capital & Coast and Hutt Valley 2021-08-13 14907
# 568 Capital & Coast and Hutt Valley 2021-08-20 15078
# 569 Capital & Coast and Hutt Valley 2021-08-27 15273
# 570 Capital & Coast and Hutt Valley 2021-09-03 15411
# 571 Capital & Coast and Hutt Valley 2021-09-10 15390
# 572 Capital & Coast and Hutt Valley 2022-09-03 15345

# %% [markdown]
# ### Next
#
# Having gathered job seeking data and renaming the regions, can now combine with Jack's data
#
# ### Important to note that this is where I am manually loading in the csv Jack has used as my shitty OS won't unzip :(

# %%
population_data <- "PopulationData.csv" %>% #Jack's code
    read_csv() %>%
    select(Region, Population)


population_data[population_data == 'Waitemat<U+0101>               	'] <- 'Waitemata'
east_coast_dhbs <- c('Hawke\'s Bay', 'Tair<U+0101>whiti')

east_coast <- population_data %>%
    filter(Region %in% east_coast_dhbs) 
east_coast_population <- sum(east_coast$Population)

population_data <- population_data %>%
    filter(!(Region %in% east_coast_dhbs)) %>%
    add_row(Region = 'East Coast', Population = east_coast_population)

population_data <- population_data %>% 
    filter(Region != 'Other region') %>%
    filter(Region != 'Lakes')
# Out:
# New names:
# * `` -> ...1
#
# Rows: 18 Columns: 3
#
# -- Column specification --------------------------------------------------------
# Delimiter: ","
# chr (1): Region
# dbl (2): ...1, Population
#
#
# i Use `spec()` to retrieve the full column specification for this data.
# i Specify the column types or set `show_col_types = FALSE` to quiet this message.

# %%
#regions and populations in Jack's data
population_data %>%
    select(Region, Population) %>%
    distinct()
# Out:
#    Region                          Population
# 1  Bay of Plenty                    259090
# 2  Canterbury                       578290
# 3  MidCentral                       186190
# 4  Nelson Marlborough               159360
# 5  Northland                        193170
# 6  South Canterbury                  61955
# 7  Southern                         344900
# 8  Taranaki                         124380
# 9  Waikato                          435690
# 10 Wairarapa                         48480
# 11 Waitemat<U+0101>                 628770
# 12 West Coast                        32550
# 13 Whanganui                         68395
# 14 Auckland                        1072640
# 15 Capital & Coast and Hutt Valley  477430
# 16 East Coast                       225865

# %%
#merging the two sets on the regions
merged_data <- monthly_job_data %>% inner_join(population_data, by='Region')
merged_data
# Out:
#     class          category indicator_name
# 1   Income support Benefits Jobseeker support by MSD region
# 2   Income support Benefits Jobseeker support by MSD region
# 3   Income support Benefits Jobseeker support by MSD region
# 4   Income support Benefits Jobseeker support by MSD region
# 5   Income support Benefits Jobseeker support by MSD region
# 6   Income support Benefits Jobseeker support by MSD region
# 7   Income support Benefits Jobseeker support by MSD region
# 8   Income support Benefits Jobseeker support by MSD region
# 9   Income support Benefits Jobseeker support by MSD region
# 10  Income support Benefits Jobseeker support by MSD region
# 11  Income support Benefits Jobseeker support by MSD region
# 12  Income support Benefits Jobseeker support by MSD region
# 13  Income support Benefits Jobseeker support by MSD region
# 14  Income support Benefits Jobseeker support by MSD region
# 15  Income support Benefits Jobseeker support by MSD region
# 16  Income support Benefits Jobseeker support by MSD region
# 17  Income support Benefits Jobseeker support by MSD region
# 18  Income support Benefits Jobseeker support by MSD region
# 19  Income support Benefits Jobseeker support by MSD region
#
# Have simplified the function extracting and wrangling the original data and have got it working on all 4 available datasets

# %%
# function to wrangle average health trust data by region for different xlsx files so can be plotted against each other
regions = c('Northland', "Auckland", "Waikato", "Bay of Plenty", "Gisborne/Hawke's Bay", 'Taranaki', 'Manawatu-Whanganui', 'Wellington', 
            'Nelson/Tasman/Marlborough/West Coast', 'Nelson/Tasman/ Marlborough/West Coast', 'Canterbury', 'Otago', 'Southland')

extract_trust <- function(wellbeing_period){
    wellbeing_df <- read_xlsx(wellbeing_period, sheet=5, skip=5) #read in xlsx, 5th sheet, skipping first 5 rows
    regionalwb_df <- wellbeing_df %>% select_if(colnames(wellbeing_df) %in% regions) #selecting columns for regions and their data only
    health_trust_row_num <- which(wellbeing_df %>% select(1) == 'Trust held for health system') + 5 #row num for row containing data on average trust
    ave_trust_df <- regionalwb_df[health_trust_row_num,] #dataframe of just ave rating row
    ave_trust_df <- ave_trust_df %>% gather('Regions', Average_rating, 1:12) #tidy data
    ave_trust_df <- ave_trust_df %>% mutate(Average_rating = as.double(Average_rating)) #changing col data type for plotting functionality
    return(ave_trust_df)
}

# %%
suppressMessages(march21_trust <- extract_trust('wellbeing-statistics-March-2021-quarter.xlsx'))
suppressMessages(dec20_trust <- extract_trust('wellbeing-statistics-december-2020-quarter.xlsx'))
suppressMessages(sept20_trust <- extract_trust('wellbeing-statistics-september-2020-quarter.xlsx'))
suppressMessages(june20_trust <- extract_trust('wellbeing-statistics-june-2020-quarter.xlsx')) #hiding output of default col names

# %%
#function to add col of dates for each quarter tibble

add_date_col <- function(trust_quarter, n, value){
    date <- rep(value, n)
    trust_quarter <- trust_quarter %>% add_column(date)
    return(trust_quarter)
}

# %%
#giving each df a date col

march21_trust <- march21_trust %>% add_date_col(n=nrow(march21_trust), value='March 2021')
dec20_trust <- dec20_trust %>% add_date_col(n=nrow(dec20_trust), value='Dec 2020')
sept20_trust <- sept20_trust %>% add_date_col(n=nrow(sept20_trust), value='Sept 2020')
june20_trust <- june20_trust %>% add_date_col(n=nrow(june20_trust), value='June 2020')

# %%
#binding all the df's into one

trust_df <- bind_rows(june20_trust, sept20_trust, dec20_trust, march21_trust)

# %%
#plot of the change in average trust of the health system for regions over 

trust_df %>% mutate(date= fct_relevel(date, 'June 2020', 'Sept 2020', 'Dec 2020', 'March 2021')) %>% #setting order for x-axis
    ggplot(aes(x=date, y=Average_rating, group=Regions)) + 
    geom_line(lwd=1, aes(color = Regions)) + 
    expand_limits(y = c(5, 10)) + geom_point()
# Out:
# plot without title

# %%
trust_df %>% ggplot(aes(x=Regions, y=Average_rating, group = date)) + 
    geom_line(lwd=1, aes(color = date)) + 
    expand_limits(y = c(0, 10)) + geom_point()
# Out:
# plot without title

# %% [markdown]
# ## Idea fail
#
# Just realized we can't really combine the vaccine data as the vaccine date is only available for this year, whereas this data is only from last year up until march so we don't have any overlap which is frustrating. Was thinking we could take an average vaccination rate for the given months and plot them against the first plot generated above.
